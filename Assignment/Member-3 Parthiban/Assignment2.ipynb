# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from matplotlib import pyplot as pt

# %%
# %matplotlib inline

# %%
data=pd.read_csv('/content/data.csv')

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
sns.displot(data.Tenure)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e2664fb25db1> in <module>
# ----> 1 sns.displot(data.Tenure)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Tenure'

# %%
sns.displot(data.texture_mean)

# %%
data.plot.line()

# %%
sns.lmplot("id","radius_mean",data,hue="diagnosis",fit_reg=False);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data=pd.read_csv("data.csv")
pd.isnull(data["diagnosis"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# Name: diagnosis, Length: 569, dtype: bool

# %%
data["texture_mean"]=np.where(data["texture_mean"]>10,np.median,data["texture_mean"])
data["texture_mean"]
# Out:
# 0      <function median at 0x7f32674fab00>
# 1      <function median at 0x7f32674fab00>
# 2      <function median at 0x7f32674fab00>
# 3      <function median at 0x7f32674fab00>
# 4      <function median at 0x7f32674fab00>
#                       ...
# 564    <function median at 0x7f32674fab00>
# 565    <function median at 0x7f32674fab00>
# 566    <function median at 0x7f32674fab00>
# 567    <function median at 0x7f32674fab00>
# 568    <function median at 0x7f32674fab00>
# Name: texture_mean, Length: 569, dtype: object

# %%
pd.get_dummies(data, columns=["diagnosis","id"],prefix=["id","diagnosis"])
data.head()
# Out:
#          id diagnosis  radius_mean                         texture_mean  \
# 0    842302         M        17.99  <function median at 0x7f32674fab00>
# 1    842517         M        20.57  <function median at 0x7f32674fab00>
# 2  84300903         M        19.69  <function median at 0x7f32674fab00>
# 3  84348301         M        11.42  <function median at 0x7f32674fab00>
# 4  84358402         M        20.29  <function median at 0x7f32674fab00>
#
#    perimeter_mean  area_mean  smoothness_mean  compactness_mean  \
# 0          122.80     1001.0          0.11840           0.27760
# 1          132.90     1326.0          0.08474           0.07864
# 2          130.00     1203.0          0.10960           0.15990
# 3           77.58      386.1          0.14250           0.28390
# 4          135.10     1297.0          0.10030           0.13280
#
#    concavity_mean  concave points_mean  ...  texture_worst  perimeter_worst  \
# ...

# %%
x=data.iloc[:, :-1].values
print(x)
# Out:
# [[842302 'M' 17.99 ... 0.2654 0.4601 0.1189]
#  [842517 'M' 20.57 ... 0.186 0.275 0.08902]
#  [84300903 'M' 19.69 ... 0.243 0.3613 0.08758]
#  ...
#  [926954 'M' 16.6 ... 0.1418 0.2218 0.0782]
#  [927241 'M' 20.6 ... 0.265 0.4087 0.124]
#  [92751 'B' 7.76 ... 0.0 0.2871 0.07039]]

# %%
y=data.iloc[:, -2].values
print(y)
# Out:
# [0.1189  0.08902 0.08758 0.173   0.07678 0.1244  0.08368 0.1151  0.1072
#  0.2075  0.08452 0.1048  0.1023  0.06287 0.1431  0.1341  0.08216 0.1142
#  0.07615 0.07259 0.08183 0.07773 0.09946 0.07526 0.09564 0.1059  0.1275
#  0.07421 0.09876 0.07919 0.09782 0.1402  0.08482 0.1123  0.1233  0.08633
#  0.1014  0.06169 0.05504 0.1071  0.07146 0.09606 0.1038  0.1027  0.09618
#  0.09185 0.07409 0.1179  0.08301 0.06917 0.06563 0.08025 0.07408 0.07987
#  0.07873 0.07036 0.08294 0.1094  0.06289 0.09026 0.0802  0.07712 0.1132
#  0.0849  0.1031  0.08911 0.09211 0.06641 0.1175  0.0641  0.06589 0.1084
#  0.1339  0.103   0.07609 0.06387 0.07191 0.1108  0.09964 0.07918 0.08851
#  0.1016  0.1051  0.09203 0.07924 0.08579 0.06846 0.09288 0.09261 0.08473
#  0.07246 0.06828 0.06206 0.06603 0.08234 0.08368 0.07376 0.08988 0.08756
#  0.09353 0.07397 0.09382 0.06878 0.0849  0.07552 0.1405  0.09097 0.07185
#  0.09789 0.08832 0.08468 0.08486 0.1082  0.09026 0.1017  0.08541 0.07722
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
data[["id"]]=scaler.fit_transform(data[["id"]])
print(data)
# Out:
#            id diagnosis  radius_mean                         texture_mean  \
# 0    0.000915         M        17.99  <function median at 0x7f32674fab00>
# 1    0.000915         M        20.57  <function median at 0x7f32674fab00>
# 2    0.092495         M        19.69  <function median at 0x7f32674fab00>
# 3    0.092547         M        11.42  <function median at 0x7f32674fab00>
# 4    0.092559         M        20.29  <function median at 0x7f32674fab00>
# ..        ...       ...          ...                                  ...
# 564  0.001007         M        21.56  <function median at 0x7f32674fab00>
# 565  0.001007         M        20.13  <function median at 0x7f32674fab00>
# 566  0.001008         M        16.60  <function median at 0x7f32674fab00>
# 567  0.001008         M        20.60  <function median at 0x7f32674fab00>
# 568  0.000092         B         7.76  <function median at 0x7f32674fab00>
#
#      perimeter_mean  area_mean  smoothness_mean  compactness_mean  \
# ...

# %%
from sklearn.model_selection import train_test_split
train_size=0.8
x=data.drop(columns=['texture_mean']).copy()
y=data['texture_mean']
x_train, x_rem, y_train, y_rem=train_test_split(x,y,train_size=0.8)
test_size=0.5
x_valid, x_test, y_valid, y_test=train_test_split(x_rem, y_rem, test_size=0.5)
print(x_train.shape), print(y_train.shape)
print(x_valid.shape), print(y_valid.shape)
# Out:
# (455, 32)
# (455,)
# (57, 32)
# (57,)
# (None, None)
