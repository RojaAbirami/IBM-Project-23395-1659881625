# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from matplotlib import pyplot as pt

# %%
# %matplotlib inline

# %%
df = pd.read_csv('/content/data.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
sns.displot(df.radius_mean)

# %%
df.plot.line()

# %%
sns.lmplot("id","area_mean",df,hue="diagnosis",fit_reg=False);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df = pd.read_csv("data.csv")
pd.isnull(df["diagnosis"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# Name: diagnosis, Length: 569, dtype: bool

# %%
df["texture_mean"] = np.where(df["texture_mean"]>10,np.median,df["texture_mean"])
df["texture_mean"]
# Out:
# 0      <function median at 0x7f05fb954b00>
# 1      <function median at 0x7f05fb954b00>
# 2      <function median at 0x7f05fb954b00>
# 3      <function median at 0x7f05fb954b00>
# 4      <function median at 0x7f05fb954b00>
#                       ...
# 564    <function median at 0x7f05fb954b00>
# 565    <function median at 0x7f05fb954b00>
# 566    <function median at 0x7f05fb954b00>
# 567    <function median at 0x7f05fb954b00>
# 568    <function median at 0x7f05fb954b00>
# Name: texture_mean, Length: 569, dtype: object

# %%
pd.get_dummies(df, columns=["diagnosis","id"],prefix=["id","diagnosis"])
df.head()
# Out:
#          id diagnosis                          radius_mean  \
# 0    842302         M  <function median at 0x7f05fb954b00>
# 1    842517         M  <function median at 0x7f05fb954b00>
# 2  84300903         M  <function median at 0x7f05fb954b00>
# 3  84348301         M  <function median at 0x7f05fb954b00>
# 4  84358402         M  <function median at 0x7f05fb954b00>
#
#                           texture_mean  perimeter_mean  area_mean  \
# 0  <function median at 0x7f05fb954b00>          122.80     1001.0
# 1  <function median at 0x7f05fb954b00>          132.90     1326.0
# 2  <function median at 0x7f05fb954b00>          130.00     1203.0
# 3  <function median at 0x7f05fb954b00>           77.58      386.1
# 4  <function median at 0x7f05fb954b00>          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# ...

# %%
x = df.iloc[:, :-1].values
print(x)
# Out:
# [[842302 'M' <function median at 0x7f05fb954b00> ... 0.2654 0.4601 0.1189]
#  [842517 'M' <function median at 0x7f05fb954b00> ... 0.186 0.275 0.08902]
#  [84300903 'M' <function median at 0x7f05fb954b00> ... 0.243 0.3613
#   0.08758]
#  ...
#  [926954 'M' <function median at 0x7f05fb954b00> ... 0.1418 0.2218 0.0782]
#  [927241 'M' <function median at 0x7f05fb954b00> ... 0.265 0.4087 0.124]
#  [92751 'B' 7.76 ... 0.0 0.2871 0.07039]]

# %%
y = df.iloc[:, -3].values
print(y)
# Out:
# [0.4601 0.275  0.3613 0.6638 0.2364 0.3985 0.3063 0.3196 0.4378 0.4366
#  0.2948 0.3792 0.3176 0.2809 0.3596 0.4218 0.3029 0.3706 0.2768 0.2977
#  0.3184 0.245  0.4667 0.2822 0.3613 0.4066 0.4264 0.2341 0.4027 0.2756
#  0.3444 0.4761 0.353  0.3672 0.427  0.4863 0.3591 0.1987 0.1565 0.2807
#  0.2994 0.2964 0.467  0.3739 0.3693 0.3799 0.3105 0.39   0.2747 0.2871
#  0.2433 0.2346 0.2785 0.3021 0.2675 0.3306 0.3537 0.3698 0.2439 0.322
#  0.3557 0.2972 0.2844 0.3282 0.3383 0.3321 0.2878 0.24   0.4228 0.2383
#  0.2551 0.2254 0.3313 0.2589 0.2618 0.265  0.271  0.3751 0.544  0.2779
#  0.2762 0.3527 0.2355 0.2311 0.3379 0.3695 0.302  0.3956 0.2972 0.3151
#  0.2522 0.2556 0.2027 0.2678 0.2834 0.3689 0.2227 0.1934 0.2772 0.2718
#  0.2651 0.2932 0.2694 0.2622 0.2826 0.3147 0.2806 0.2983 0.4055 0.2829
#  0.2533 0.2226 0.2398 0.2383 0.2926 0.2438 0.1652 0.3585 0.3274 0.4882
#  0.3016 0.2894 0.3222 0.2889 0.2048 0.2364 0.347  0.2841 0.259  0.3305
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[["id"]] = scaler.fit_transform(df[["id"]])
print(df)
# Out:
#            id diagnosis                          radius_mean  \
# 0    0.000915         M  <function median at 0x7f05fb954b00>
# 1    0.000915         M  <function median at 0x7f05fb954b00>
# 2    0.092495         M  <function median at 0x7f05fb954b00>
# 3    0.092547         M  <function median at 0x7f05fb954b00>
# 4    0.092559         M  <function median at 0x7f05fb954b00>
# ..        ...       ...                                  ...
# 564  0.001007         M  <function median at 0x7f05fb954b00>
# 565  0.001007         M  <function median at 0x7f05fb954b00>
# 566  0.001008         M  <function median at 0x7f05fb954b00>
# 567  0.001008         M  <function median at 0x7f05fb954b00>
# 568  0.000092         B                                 7.76
#
#                             texture_mean  perimeter_mean  area_mean  \
# 0    <function median at 0x7f05fb954b00>          122.80     1001.0
# 1    <function median at 0x7f05fb954b00>          132.90     1326.0
# ...

# %%
from sklearn.model_selection import train_test_split
train_size = 0.8
x = df.drop(columns = ['diagnosis']).copy()
y = df['diagnosis']
x_train, x_rem, y_train, y_rem = train_test_split(x,y,train_size=0.8)
test_size = 0.5
x_valid, x_test, y_valid, y_test = train_test_split(x_rem,y_rem,test_size=0.5)
print(x_train.shape),print(y_train.shape)
print(x_valid.shape),print(y_valid.shape)
print(x_test.shape),print(y_test.shape)
# Out:
# (455, 32)
# (455,)
# (57, 32)
# (57,)
# (57, 32)
# (57,)
# (None, None)
